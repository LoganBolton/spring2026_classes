# %% [markdown]
# # Naive Bayes

# %% [markdown]
# 1. Compute and show the conditional probability distribution for each feature. Explain how you got these values and show your work. Note: You are expected to do this part of the question by hand. Explain how you got the probability distribution for at least two features in detail

# %%
import pandas as pd
import math

file = "Asssignment4_Data.xlsx"
sheet = "Train"

df = pd.read_excel(file)
df = df.drop(columns=["House ID"])

target = "Construction type"
features = [col for col in df.columns if col != target]

print("Class priors:\n")
print(df[target].value_counts(normalize=True))
print()

for feature in features:
    print("=" * 50)
    print("Feature:", feature)

    grouped = df.groupby(target)[feature]

    means = grouped.mean()
    variances = grouped.var(ddof=0)

    print("\nMeans:")
    print(means)
    print("\nVariances:")
    print(variances)
    print()
# Out:
# Class priors:
#
# Construction type
# Apartment    0.35
# House        0.35
# Condo        0.30
# Name: proportion, dtype: float64
#
# ...
# Feature: Local Price
#
# Means:
# Construction type
# Apartment    7.332743
# Condo        7.415900
# House        5.760743
# Name: Local Price, dtype: float64
#
# Variances:
# Construction type
# Apartment    11.207517
# Condo        17.719672
# House         0.278604
# Name: Local Price, dtype: float64
#
# ...
# Feature: Bathrooms
#
# Means:
# Construction type
# Apartment    1.285714
# Condo        1.333333
# House        1.071429
# Name: Bathrooms, dtype: float64
#
# Variances:
# Construction type
# Apartment    0.275510
# Condo        0.305556
# House        0.030612
# Name: Bathrooms, dtype: float64
#
# ...
# Feature: Land Area
#
# Means:
# Construction type
# Apartment    6.103857
# Condo        6.024667
# House        6.630900
# Name: Land Area, dtype: float64
#
# Variances:
# Construction type
# Apartment    9.101044
# Condo        5.396577
# ...

# %% [markdown]
# The class priors are:
#
# $$
# P(\text{Apartment}) = \frac{7}{20} = 0.35
# $$
#
# $$
# P(\text{House}) = \frac{7}{20} = 0.35
# $$
#
# $$
# P(\text{Condo}) = \frac{6}{20} = 0.30
# $$
#
# I then computed the mean and variance of local price and land area for each construction type.
#
# For Apartments, the Local Price values are:
#
# $$
# 4.9176,\ 4.5573,\ 5.0597,\ 14.4598,\ 5.05,\ 8.2464,\ 9.0384
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Local Price} \mid \text{Apartment}}
# =
# \frac{4.9176+4.5573+5.0597+14.4598+5.05+8.2464+9.0384}{7}
# =
# 7.332743
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Local Price} \mid \text{Apartment}}
# =
# \frac{
# (4.9176-7.332743)^2+
# (4.5573-7.332743)^2+
# (5.0597-7.332743)^2+
# (14.4598-7.332743)^2+
# (5.05-7.332743)^2+
# (8.2464-7.332743)^2+
# (9.0384-7.332743)^2
# }{7}
# =
# 11.207517
# $$
#
# Therefore,
#
# $$
# \text{Local Price} \mid \text{Apartment} \sim \mathcal{N}(7.332743,\ 11.207517)
# $$
#
# For Houses, the Local Price values are:
#
# $$
# 5.0208,\ 5.6039,\ 5.8282,\ 5.3003,\ 6.2712,\ 5.6039,\ 6.6969
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Local Price} \mid \text{House}}
# =
# \frac{5.0208+5.6039+5.8282+5.3003+6.2712+5.6039+6.6969}{7}
# =
# 5.760743
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Local Price} \mid \text{House}}
# =
# \frac{
# (5.0208-5.760743)^2+
# (5.6039-5.760743)^2+
# (5.8282-5.760743)^2+
# (5.3003-5.760743)^2+
# (6.2712-5.760743)^2+
# (5.6039-5.760743)^2+
# (6.6969-5.760743)^2
# }{7}
# =
# 0.278604
# $$
#
# Therefore,
#
# $$
# \text{Local Price} \mid \text{House} \sim \mathcal{N}(5.760743,\ 0.278604)
# $$
#
# For Condos, the Local Price values are:
#
# $$
# 4.5429,\ 3.891,\ 5.898,\ 16.4202,\ 5.9592,\ 7.7841
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Local Price} \mid \text{Condo}}
# =
# \frac{4.5429+3.891+5.898+16.4202+5.9592+7.7841}{6}
# =
# 7.415900
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Local Price} \mid \text{Condo}}
# =
# \frac{
# (4.5429-7.4159)^2+
# (3.891-7.4159)^2+
# (5.898-7.4159)^2+
# (16.4202-7.4159)^2+
# (5.9592-7.4159)^2+
# (7.7841-7.4159)^2
# }{6}
# =
# 17.719672
# $$
#
# Therefore,
#
# $$
# \text{Local Price} \mid \text{Condo} \sim \mathcal{N}(7.415900,\ 17.719672)
# $$
#
# For Apartments, the Land Area values are:
#
# $$
# 3.472,\ 4.05,\ 4.455,\ 12.8,\ 5,\ 5.15,\ 7.8
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Land Area} \mid \text{Apartment}}
# =
# \frac{3.472+4.05+4.455+12.8+5+5.15+7.8}{7}
# =
# 6.103857
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Land Area} \mid \text{Apartment}}
# =
# \frac{
# (3.472-6.103857)^2+
# (4.05-6.103857)^2+
# (4.455-6.103857)^2+
# (12.8-6.103857)^2+
# (5-6.103857)^2+
# (5.15-6.103857)^2+
# (7.8-6.103857)^2
# }{7}
# =
# 9.101044
# $$
#
# Therefore,
#
# $$
# \text{Land Area} \mid \text{Apartment} \sim \mathcal{N}(6.103857,\ 9.101044)
# $$
#
# For Houses, the Land Area values are:
#
# $$
# 3.531,\ 9.52,\ 6.435,\ 4.9883,\ 5.52,\ 9.52,\ 6.902
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Land Area} \mid \text{House}}
# =
# \frac{3.531+9.52+6.435+4.9883+5.52+9.52+6.902}{7}
# =
# 6.630900
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Land Area} \mid \text{House}}
# =
# \frac{
# (3.531-6.6309)^2+
# (9.52-6.6309)^2+
# (6.435-6.6309)^2+
# (4.9883-6.6309)^2+
# (5.52-6.6309)^2+
# (9.52-6.6309)^2+
# (6.902-6.6309)^2
# }{7}
# =
# 4.335326
# $$
#
# Therefore,
#
# $$
# \text{Land Area} \mid \text{House} \sim \mathcal{N}(6.630900,\ 4.335326)
# $$
#
# For Condos, the Land Area values are:
#
# $$
# 2.275,\ 4.455,\ 5.85,\ 9.8,\ 6.666,\ 7.102
# $$
#
# So the mean is
#
# $$
# \mu_{\text{Land Area} \mid \text{Condo}}
# =
# \frac{2.275+4.455+5.85+9.8+6.666+7.102}{6}
# =
# 6.024667
# $$
#
# The variance is
#
# $$
# \sigma^2_{\text{Land Area} \mid \text{Condo}}
# =
# \frac{
# (2.275-6.024667)^2+
# (4.455-6.024667)^2+
# (5.85-6.024667)^2+
# (9.8-6.024667)^2+
# (6.666-6.024667)^2+
# (7.102-6.024667)^2
# }{6}
# =
# 5.396577
# $$
#
# Therefore,
#
# $$
# \text{Land Area} \mid \text{Condo} \sim \mathcal{N}(6.024667,\ 5.396577)
# $$

# %% [markdown]
# 2. Using your conditional probability table, write a Python code that will compute the probabilities for each example in the test data. Your program should output the probabilities of each class as well as the final classification based on the MAP rule. Note: You should hard-code the conditional probabilities from the previous step into your code

# %%
df = pd.read_excel("Asssignment4_Data.xlsx", sheet_name="Test")
df = df.drop(columns=["House ID"])
df = df.drop(columns=["Construction type"])

priors = {
    "Apartment": 0.35,
    "House": 0.35,
    "Condo": 0.30
}

means = {
    "Apartment": {
        "Local Price": 7.332743,
        "Bathrooms": 1.285714,
        "Land Area": 6.103857,
        "Living area": 1.505000,
        "# Garages": 1.214286,
        "# Rooms": 6.857143,
        "# Bedrooms": 3.428571,
        "Age of home": 38.714286
    },
    "House": {
        "Local Price": 5.760743,
        "Bathrooms": 1.071429,
        "Land Area": 6.630900,
        "Living area": 1.391714,
        "# Garages": 1.071429,
        "# Rooms": 6.142857,
        "# Bedrooms": 3.000000,
        "Age of home": 34.285714
    },
    "Condo": {
        "Local Price": 7.415900,
        "Bathrooms": 1.333333,
        "Land Area": 6.024667,
        "Living area": 1.553333,
        "# Garages": 1.333333,
        "# Rooms": 6.833333,
        "# Bedrooms": 3.333333,
        "Age of home": 39.666667
    }
}

vars = {
    "Apartment": {
        "Local Price": 11.207517,
        "Bathrooms": 0.275510,
        "Land Area": 9.101044,
        "Living area": 0.424941,
        "# Garages": 0.418367,
        "# Rooms": 1.551020,
        "# Bedrooms": 0.816327,
        "Age of home": 184.775510
    },
    "House": {
        "Local Price": 0.278604,
        "Bathrooms": 0.030612,
        "Land Area": 4.335326,
        "Living area": 0.038860,
        "# Garages": 0.602041,
        "# Rooms": 0.408163,
        "# Bedrooms": 0.285714,
        "Age of home": 138.775510
    },
    "Condo": {
        "Local Price": 17.719672,
        "Bathrooms": 0.305556,
        "Land Area": 5.396577,
        "Living area": 0.710620,
        "# Garages": 0.222222,
        "# Rooms": 2.138889,
        "# Bedrooms": 0.555556,
        "Age of home": 162.222222
    }
}

def gaussian(x, mean, var):
    top = math.exp(-((x - mean) ** 2) / (2 * var))
    bottom = math.sqrt(2 * math.pi * var)
    return top / bottom

for i in range(len(df)):
    row = df.iloc[i]

    apartment_prob = priors["Apartment"]
    house_prob = priors["House"]
    condo_prob = priors["Condo"]

    for col in df.columns:
        x = row[col]

        apartment_prob *= gaussian(x, means["Apartment"][col], vars["Apartment"][col])
        house_prob *= gaussian(x, means["House"][col], vars["House"][col])
        condo_prob *= gaussian(x, means["Condo"][col], vars["Condo"][col])

    total = apartment_prob + house_prob + condo_prob

    apartment_prob = apartment_prob / total
    house_prob = house_prob / total
    condo_prob = condo_prob / total

    if apartment_prob >= house_prob and apartment_prob >= condo_prob:
        prediction = "Apartment"
    elif house_prob >= apartment_prob and house_prob >= condo_prob:
        prediction = "House"
    else:
        prediction = "Condo"

    print("Example", i + 1)
    print("P(Apartment | x) =", round(apartment_prob, 6))
    print("P(House | x) =", round(house_prob, 6))
    print("P(Condo | x) =", round(condo_prob, 6))
    print("Predicted class =", prediction)
    print()
# Out:
# Example 1
# P(Apartment | x) = 0.115466
# P(House | x) = 0.775428
# P(Condo | x) = 0.109106
# Predicted class = House
#
# Example 2
# P(Apartment | x) = 0.655012
# P(House | x) = 0.0
# P(Condo | x) = 0.344988
# Predicted class = Apartment
#
# Example 3
# P(Apartment | x) = 0.75597
# P(House | x) = 0.003366
# P(Condo | x) = 0.240664
# Predicted class = Apartment
#
# Example 4
# P(Apartment | x) = 0.513586
# P(House | x) = 0.0
# P(Condo | x) = 0.486414
# Predicted class = Apartment
#
# Example 5
# P(Apartment | x) = 0.466865
# P(House | x) = 0.0
# P(Condo | x) = 0.533135
# Predicted class = Condo

# %% [markdown]
# # Decision Tree
